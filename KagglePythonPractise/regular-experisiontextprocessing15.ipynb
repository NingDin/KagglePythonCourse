# %%
pd[col].str.split(" ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/1309780894.py in <module>
# ----> 1 pd[col].str.split(" ")
#
# NameError: name 'pd' is not defined

# %%
pd.str.strip('[]') # take away [] from beginning and end of the str
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/1430202913.py in <module>
# ----> 1 pd.str.strip('[]') # take away [] from beginning and end of the str
#
# NameError: name 'pd' is not defined

# %%
pd[col].str.cat()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/1464783903.py in <module>
# ----> 1 pd.str.cat()
#
# NameError: name 'pd' is not defined

# %%
pd[col].str.slice(0,10).head(8) # get first 10 character only
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/2795475155.py in <module>
# ----> 1 pd[col].str.slice(0,10)
#
# NameError: name 'pd' is not defined

# %%
pd[col].str.slice_replace(5,10,'wolves Rule!').head(8) # place slicer 5-10 for every row with wolves rule
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/866328876.py in <module>
# ----> 1 pd[col].str.slice_replace(5,10,'wolves Rule!').head(8) # place slicer 5-10 for every row with wolves rule
#
# NameError: name 'pd' is not defined

# %%
pd[col].str.replace('wolves','Pups') # hear replace all word wolves with pups
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/3565532566.py in <module>
# ----> 1 pd[col].str.replace('wolves','Pups') # hear replace all word wolves with pups
#
# NameError: name 'pd' is not defined

# %%
# look up certain str word
logical_index=pd[col].str.lower().str.contains('wigg|drew')
pd[col][logical_index].head(10)
#show the location

# %%
# regular expression  # help match the str of  diff types
#example   :     "."-the period is a metacharacter that matches any character other than a newline

# %%
my_series=pd.Series(['will','bill','Till','still','gull'])
my_series.str.contains('.ill') # . is the regular experission will return a series of bool with last one gull as false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/2643346767.py in <module>
# ----> 1 my_series=pd.Series(['will','bill','Till','still','gull'])
#       2 my_series.str.contains('.ill') # . is the regular experission will return a series of bool with last one gull as false
#
# NameError: name 'pd' is not defined

# %%
# [] provide a set of character match eg "[w,b]ill"  find will and bill
my_series.str.contains('[Tt]ill')  # still will return a series of bool
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/1252837545.py in <module>
#       1 # [] provide a set of character match eg "[w,b]ill"  find will and bill
# ----> 2 my_series.str.contains('[Tt]ill')  # still will return a series of bool
#
# NameError: name 'my_series' is not defined

# %%
# we can use regular exp in build in python - import re

# %%
str.contains()
str.replace()
#both support regular expression
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_27/2106495814.py in <module>
# ----> 1 str.contains()
#       2 str.replace()
#       3 #both support regular expression
#
# AttributeError: type object 'str' has no attribute 'contains'

# %%
str.count() # count occurance of a given pattern
# pd[col].str.count(r'[Ww]olves').head(8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/3525842408.py in <module>
# ----> 1 str.count() # count occurance of a given pattern
#       2 # pd[col].str.count(r'[Ww]olves').head(8)
#
# TypeError: descriptor 'count' of 'str' object needs an argument

# %%
pd[col].str.findall(r'[Ww]olves').head(8)  # return as a list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/1242822311.py in <module>
# ----> 1 pd[col].str.findall(r'[Ww]olves').head(8)
#
# NameError: name 'pd' is not defined

# %%
# get weblinks
web_links=comments.str.contains(r'https?:')  # ? wild card s is optional ; return a logical index
posts_with_links=comments[web_links]
print(len(post_with_links))
posted_with_links.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/3023783191.py in <module>
#       1 # get weblinks
# ----> 2 web_links=comments.str.contains(r'https?:')  # ? wild card s is optional
#       3 posts_with_links=comments[web_links]
#       4 print(len(post_with_links))
#       5 posted_with_links.head(5)
#
# NameError: name 'comments' is not defined

# %%
# more specific way
only_links=posts_with_links.str.findall(r'https?:[^ \n\)]+') # ^ mathc not space; \n not a new line character; \)- skip meta exp for )
# \)---not a ); + we need have sth else after not empty 
only_links.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/4003907540.py in <module>
#       1 # more specific way
# ----> 2 only_links=posts_with_links.str.findall(r'https?:[^ \n\)]+')
#       3 only_links.head(10)
#
# NameError: name 'posts_with_links' is not defined

# %%
# maybe serach internet to find a better way to match the link # no need to reinviting the wheels
